# %%
# loading sales file from AWS s3

df_load_sales = spark.read.csv("s3://amazon-l0-landing-prod/landing/sales/sales.csv", header=True, inferSchema=True)

df_load_sales.createOrReplaceTempView("df_load_sales")

spark.sql("select * from df_load_sales limit 10").show()
# Out:
# +-----------+-------+---------+----------+----+----+----+--------+----------+---------------+
# |Customer ID|Terr ID|Market ID|Product ID| NRx|NBRx| TRx| Revenue| Sale Date|  Customer Type|
# +-----------+-------+---------+----------+----+----+----+--------+----------+---------------+
# |   ID135600| 134314|     4001|      1002|1500| 196|2181|$43,833 |2025-02-07|        Clinics|
# |   ID135601| 134303|     4001|      1000|1194| 237|1797|$48,717 |2024-08-08|        Clinics|
# |   ID135602| 134307|     4004|      1000| 618|1457|2162| $8,744 |2025-06-15|      Hospitals|
# |   ID135603| 134293|     4004|      1000|1455| 123|1918|$25,321 |2025-07-15|       Pharmacy|
# |   ID135604| 134310|     4002|      1003| 130|1304|1458|$13,669 |2024-08-13|        Clinics|
# |   ID135605| 134296|     4001|      1003| 619| 717|1625| $7,552 |2024-12-05|      Hospitals|
# |   ID135606| 134320|     4002|      1000|1779| 100|2148|$48,563 |2024-08-08|      Hospitals|
# |   ID135607| 134323|     4001|      1000|1727| 287|2245|$13,672 |2024-12-30|Online Pharmacy|
# |   ID135608| 134323|     4000|      1003| 451|  89| 837|$45,835 |2024-11-14|   Supermarkets|
# |   ID135609| 134293|     4002|      1000|1006| 544|1768|$31,716 |2025-05-23|   Supermarkets|
# +-----------+-------+---------+----------+----+----+----+--------+----------+---------------+

# %%
# Restructuring the file

# Renaming headers
df_restructured_sales = df_load_sales.withColumnRenamed("Customer ID", "cust_id").withColumnRenamed("Terr ID", "terr_id").withColumnRenamed("Market ID", "mkt_id").withColumnRenamed("Product ID", "prod_id").withColumnRenamed("Sales Date", "sls_dt").withColumnRenamed("Customer Type", "cust_typ").withColumnRenamed("NRx", "nrx_ct").withColumnRenamed("NBRx", "nbrx_ct").withColumnRenamed("TRx", "trx_ct").withColumnRenamed("Sale Date", "sls_dt")

df_restructured_sales.createOrReplaceTempView("df_restructured_sales")

# Renaming segment values
# Adding timestamp
df_renamed_sales = spark.sql("""
                        select
                        terr_id,
                        cust_id,
                        mkt_id, 
                        prod_id,
                        cust_typ,
                        nrx_ct,
                        nbrx_ct,
                        trx_ct,
                        sls_dt,
                        now() as load_dt
                        from df_restructured_sales
                        """)

df_renamed_sales.createOrReplaceTempView("df_renamed_sales")

df_renamed_sales.show()
# Out:
# +-------+--------+------+-------+---------------+------+-------+------+----------+--------------------+
# |terr_id| cust_id|mkt_id|prod_id|       cust_typ|nrx_ct|nbrx_ct|trx_ct|    sls_dt|             load_dt|
# +-------+--------+------+-------+---------------+------+-------+------+----------+--------------------+
# | 134314|ID135600|  4001|   1002|        Clinics|  1500|    196|  2181|2025-02-07|2025-11-10 04:08:...|
# | 134303|ID135601|  4001|   1000|        Clinics|  1194|    237|  1797|2024-08-08|2025-11-10 04:08:...|
# | 134307|ID135602|  4004|   1000|      Hospitals|   618|   1457|  2162|2025-06-15|2025-11-10 04:08:...|
# | 134293|ID135603|  4004|   1000|       Pharmacy|  1455|    123|  1918|2025-07-15|2025-11-10 04:08:...|
# | 134310|ID135604|  4002|   1003|        Clinics|   130|   1304|  1458|2024-08-13|2025-11-10 04:08:...|
# | 134296|ID135605|  4001|   1003|      Hospitals|   619|    717|  1625|2024-12-05|2025-11-10 04:08:...|
# | 134320|ID135606|  4002|   1000|      Hospitals|  1779|    100|  2148|2024-08-08|2025-11-10 04:08:...|
# | 134323|ID135607|  4001|   1000|Online Pharmacy|  1727|    287|  2245|2024-12-30|2025-11-10 04:08:...|
# | 134323|ID135608|  4000|   1003|   Supermarkets|   451|     89|   837|2024-11-14|2025-11-10 04:08:...|
# | 134293|ID135609|  4002|   1000|   Supermarkets|  1006|    544|  1768|2025-05-23|2025-11-10 04:08:...|
# | 134298|ID135610|  4002|   1001|       Pharmacy|  1633|    108|  2220|2025-05-18|2025-11-10 04:08:...|
# | 134308|ID135611|  4000|   1003|Online Pharmacy|   128|    126|   258|2024-11-08|2025-11-10 04:08:...|
# | 134312|ID135612|  4002|   1003|       Pharmacy|   504|   1067|  2016|2024-08-19|2025-11-10 04:08:...|
# | 134300|ID135613|  4004|   1003|       Pharmacy|   216|    667|  1131|2025-07-08|2025-11-10 04:08:...|
# | 134298|ID135614|  4004|   1003|       Pharmacy|  1986|   1236|  3514|2024-12-03|2025-11-10 04:08:...|
# | 134311|ID135615|  4000|   1002|Online Pharmacy|  1977|   1126|  3327|2025-07-13|2025-11-10 04:08:...|
# | 134320|ID135616|  4000|   1003|        Clinics|  1320|    853|  2277|2024-08-22|2025-11-10 04:08:...|
# | 134286|ID135617|  4004|   1002|       Pharmacy|  1766|    821|  3055|2025-02-27|2025-11-10 04:08:...|
# | 134321|ID135618|  4001|   1000|Online Pharmacy|  1078|    229|  1734|2025-01-12|2025-11-10 04:08:...|
# | 134294|ID135619|  4002|   1000|        Clinics|   783|   1454|  2665|2025-01-24|2025-11-10 04:08:...|
# +-------+--------+------+-------+---------------+------+-------+------+----------+--------------------+
# only showing top 20 rows

# %%
# loading dimensions from l1 as parquet files

df_load_cust = spark.read.parquet("s3://amazon-l1-staging-prod/staging/customer/")
df_load_cust.createOrReplaceTempView("df_load_cust")

df_load_seg = spark.read.parquet("s3://amazon-l1-staging-prod/staging/segmentation/")
df_load_seg.createOrReplaceTempView("df_load_seg")

df_load_geo = spark.read.parquet("s3://amazon-l1-staging-prod/staging/geography/")
df_load_geo.createOrReplaceTempView("df_load_geo")

df_load_prod = spark.read.parquet("s3://amazon-l1-staging-prod/staging/product/")
df_load_prod.createOrReplaceTempView("df_load_prod")

df_load_seg.show()
# Out:
# +--------+-------+--------------------+
# | cust_id| seg_nm|             load_dt|
# +--------+-------+--------------------+
# |ID135600|   High|2025-11-10 02:15:...|
# |ID135601| Medium|2025-11-10 02:15:...|
# |ID135602|    Low|2025-11-10 02:15:...|
# |ID135603|    Low|2025-11-10 02:15:...|
# |ID135604|    Low|2025-11-10 02:15:...|
# |ID135605|    Low|2025-11-10 02:15:...|
# |ID135606| Medium|2025-11-10 02:15:...|
# |ID135607|   High|2025-11-10 02:15:...|
# |ID135608|   High|2025-11-10 02:15:...|
# |ID135609|Unknown|2025-11-10 02:15:...|
# |ID135610|Unknown|2025-11-10 02:15:...|
# |ID135611|Unknown|2025-11-10 02:15:...|
# |ID135612| Medium|2025-11-10 02:15:...|
# |ID135613|    Low|2025-11-10 02:15:...|
# |ID135614|    Low|2025-11-10 02:15:...|
# |ID135615|    Low|2025-11-10 02:15:...|
# |ID135616|    Low|2025-11-10 02:15:...|
# |ID135617| Medium|2025-11-10 02:15:...|
# |ID135618|   High|2025-11-10 02:15:...|
# |ID135619|   High|2025-11-10 02:15:...|
# +--------+-------+--------------------+
# only showing top 20 rows

# %%
# creating time buckets
df_tb_sales = spark.sql("""
    select
        terr_id,
        cust_id,
        mkt_id, 
        prod_id,
        concat('M', lpad(month(sls_dt), 2, '0')) as tb_nm,
        case 
            when year(sls_dt) = 2025 then 'Curr'
            when year(sls_dt) = 2024 then 'Prev'
            else null
        end as tb_typ,
        cust_typ,
        sum(nrx_ct) as nrx_ct,
        sum(nbrx_ct) as nbrx_ct,
        sum(trx_ct) as trx_ct
    from
        df_restructured_sales
    group by
        terr_id,
        cust_id,
        mkt_id, 
        prod_id,
        tb_nm,
        tb_typ,
        cust_typ

    union all

    select
        terr_id,
        cust_id,
        mkt_id, 
        prod_id,
        "Y" as tb_nm,
        case 
            when year(sls_dt) = 2025 then 'Curr'
            when year(sls_dt) = 2024 then 'Prev'
            else null
        end as tb_typ,
        cust_typ,
        sum(nrx_ct) as nrx_ct,
        sum(nbrx_ct) as nbrx_ct,
        sum(trx_ct) as trx_ct
    from
        df_restructured_sales
    group by
        terr_id,
        cust_id,
        mkt_id, 
        prod_id,
        tb_nm,
        tb_typ,
        cust_typ
""")

df_tb_sales.createOrReplaceTempView("df_tb_sales")
display(spark.sql("select distinct tb_nm, tb_typ from df_tb_sales order by tb_nm, tb_typ"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>tb_nm</th><th>tb_typ</th></tr></thead><tbody><tr><td>M01</td><td>Curr</td></tr><tr><td>M02</td><td>Curr</td></tr><tr><td>M03</td><td>Curr</td></tr><tr><td>M04</td><td>Curr</td></tr><tr><td>M05</td><td>Curr</td></tr><tr><td>M06</td><td>Curr</td></tr><tr><td>M07</td><td>Curr</td></tr><tr><td>M07</td><td>Prev</td></tr><tr><td>M08</td><td>Prev</td></tr><tr><td>M09</td><td>Prev</td></tr><tr><td>M10</td><td>Prev</td></tr><tr><td>M11</td><td>Curr</td></tr><tr><td>M11</td><td>Prev</td></tr><tr><td>M12</td><td>Prev</td></tr><tr><td>Y</td><td>Curr</td></tr><tr><td>Y</td><td>Prev</td></tr></tbody></table></div>

# %%
# bringing in product details
# broadcasting smaller table

df_prod_sales = spark.sql("""
                          select /*+ BROADCASTJOIN(df_load_prod) */
                            terr_id,
                            cust_id,
                            sales.mkt_id, 
                            mkt_nm,
                            sales.prod_id,
                            prod_nm,
                            tb_nm,
                            tb_typ,
                            cust_typ,
                            nrx_ct,
                            nbrx_ct,
                            trx_ct
                          from df_tb_sales sales
                          join
                          df_load_prod prod
                          on sales.prod_id = prod.prod_id
                          and sales.mkt_id = prod.mkt_id
                          """)

df_prod_sales.createOrReplaceTempView("df_prod_sales")
df_prod_sales.show()
# Out:
# +-------+--------+------+--------------+-------+---------+-----+------+---------------+------+-------+------+
# |terr_id| cust_id|mkt_id|        mkt_nm|prod_id|  prod_nm|tb_nm|tb_typ|       cust_typ|nrx_ct|nbrx_ct|trx_ct|
# +-------+--------+------+--------------+-------+---------+-----+------+---------------+------+-------+------+
# | 134289|ID136310|  4000|         Renal|   1001|Product B|  M04|  Curr|   Supermarkets|   506|    678|  1394|
# | 134321|ID136077|  4004|      Oncology|   1003|Product D|  M05|  Curr|   Supermarkets|  1215|     87|  1455|
# | 134318|ID136079|  4000|         Renal|   1003|Product D|  M01|  Curr|        Clinics|  1028|    451|  1914|
# | 134314|ID135871|  4003|Cardiovascular|   1003|Product D|  M04|  Curr|       Pharmacy|   504|    369|  1346|
# | 134298|ID136173|  4001|   Respiratory|   1003|Product D|  M08|  Prev|        Clinics|  1176|    221|  1431|
# | 134313|ID135953|  4000|         Renal|   1001|Product B|  M10|  Prev|   Supermarkets|   587|   1083|  1872|
# | 134318|ID136309|  4000|         Renal|   1002|Product C|  M03|  Curr|   Supermarkets|   358|    982|  1533|
# | 134322|ID135632|  4002|      Diabetes|   1003|Product D|  M06|  Curr|      Hospitals|   440|    779|  1405|
# | 134323|ID136233|  4002|      Diabetes|   1001|Product B|  M05|  Curr|      Hospitals|   793|   1473|  2540|
# | 134310|ID135894|  4002|      Diabetes|   1001|Product B|  M09|  Prev|        Clinics|  1095|    377|  1707|
# | 134314|ID136099|  4003|Cardiovascular|   1003|Product D|  M11|  Prev|      Hospitals|  1873|    592|  2531|
# | 134293|ID136503|  4001|   Respiratory|   1003|Product D|  M03|  Curr|Online Pharmacy|   872|   1267|  2359|
# | 134296|ID136025|  4002|      Diabetes|   1001|Product B|  M11|  Prev|       Pharmacy|  1423|    834|  2483|
# | 134323|ID135910|  4003|Cardiovascular|   1003|Product D|  M04|  Curr|        Clinics|   833|    357|  1206|
# | 134320|ID136558|  4003|Cardiovascular|   1003|Product D|  M11|  Prev|      Hospitals|  1435|    466|  2336|
# | 134303|ID135601|  4001|   Respiratory|   1000|Product A|  M08|  Prev|        Clinics|  1194|    237|  1797|
# | 134319|ID135765|  4000|         Renal|   1001|Product B|  M04|  Curr|      Hospitals|   667|    242|  1297|
# | 134321|ID136240|  4004|      Oncology|   1003|Product D|  M04|  Curr|      Hospitals|  1529|   1246|  3078|
# | 134319|ID136285|  4001|   Respiratory|   1000|Product A|  M07|  Prev|        Clinics|   463|   1289|  2223|
# | 134322|ID136349|  4001|   Respiratory|   1000|Product A|  M10|  Prev|Online Pharmacy|   201|    175|   641|
# +-------+--------+------+--------------+-------+---------+-----+------+---------------+------+-------+------+
# only showing top 20 rows

# %%
# bringing in customer details

df_cust_sales = spark.sql("""
                          select
                            terr_id,
                            sales.cust_id,
                            cust_nm,
                            mkt_id, 
                            mkt_nm,
                            prod_id,
                            prod_nm,
                            tb_nm,
                            tb_typ,
                            cust_typ,
                            nrx_ct,
                            nbrx_ct,
                            trx_ct
                          from df_prod_sales sales
                          join
                          df_load_cust cust
                          on sales.cust_id = cust.cust_id
                          """)
df_cust_sales.createOrReplaceTempView("df_cust_sales")
df_cust_sales.show()
# Out:
# +-------+--------+--------------------+------+--------------+-------+---------+-----+------+---------------+------+-------+------+
# |terr_id| cust_id|             cust_nm|mkt_id|        mkt_nm|prod_id|  prod_nm|tb_nm|tb_typ|       cust_typ|nrx_ct|nbrx_ct|trx_ct|
# +-------+--------+--------------------+------+--------------+-------+---------+-----+------+---------------+------+-------+------+
# | 134289|ID136310|      Stephen Becker|  4000|         Renal|   1001|Product B|  M04|  Curr|   Supermarkets|   506|    678|  1394|
# | 134321|ID136077|Kathleen Jenkins DVM|  4004|      Oncology|   1003|Product D|  M05|  Curr|   Supermarkets|  1215|     87|  1455|
# | 134318|ID136079|      Jennifer Jones|  4000|         Renal|   1003|Product D|  M01|  Curr|        Clinics|  1028|    451|  1914|
# | 134314|ID135871|     Heather Simmons|  4003|Cardiovascular|   1003|Product D|  M04|  Curr|       Pharmacy|   504|    369|  1346|
# | 134298|ID136173|   Nicholas Caldwell|  4001|   Respiratory|   1003|Product D|  M08|  Prev|        Clinics|  1176|    221|  1431|
# | 134313|ID135953|         Ariel Brown|  4000|         Renal|   1001|Product B|  M10|  Prev|   Supermarkets|   587|   1083|  1872|
# | 134318|ID136309|     Victoria Powell|  4000|         Renal|   1002|Product C|  M03|  Curr|   Supermarkets|   358|    982|  1533|
# | 134322|ID135632|    Michael Cisneros|  4002|      Diabetes|   1003|Product D|  M06|  Curr|      Hospitals|   440|    779|  1405|
# | 134323|ID136233|     Travis Carrillo|  4002|      Diabetes|   1001|Product B|  M05|  Curr|      Hospitals|   793|   1473|  2540|
# | 134310|ID135894|    Elizabeth Branch|  4002|      Diabetes|   1001|Product B|  M09|  Prev|        Clinics|  1095|    377|  1707|
# | 134314|ID136099|        Sharon Weiss|  4003|Cardiovascular|   1003|Product D|  M11|  Prev|      Hospitals|  1873|    592|  2531|
# | 134293|ID136503|        Keith Burton|  4001|   Respiratory|   1003|Product D|  M03|  Curr|Online Pharmacy|   872|   1267|  2359|
# | 134296|ID136025|          Todd Lewis|  4002|      Diabetes|   1001|Product B|  M11|  Prev|       Pharmacy|  1423|    834|  2483|
# | 134323|ID135910|     Bonnie Thompson|  4003|Cardiovascular|   1003|Product D|  M04|  Curr|        Clinics|   833|    357|  1206|
# | 134320|ID136558|       Sara Sullivan|  4003|Cardiovascular|   1003|Product D|  M11|  Prev|      Hospitals|  1435|    466|  2336|
# | 134303|ID135601|       Jackie Wagner|  4001|   Respiratory|   1000|Product A|  M08|  Prev|        Clinics|  1194|    237|  1797|
# | 134319|ID135765|         Emily Brown|  4000|         Renal|   1001|Product B|  M04|  Curr|      Hospitals|   667|    242|  1297|
# | 134321|ID136240|    Brandon Williams|  4004|      Oncology|   1003|Product D|  M04|  Curr|      Hospitals|  1529|   1246|  3078|
# | 134319|ID136285|    Andrew Hernandez|  4001|   Respiratory|   1000|Product A|  M07|  Prev|        Clinics|   463|   1289|  2223|
# | 134322|ID136349|     Emily Singleton|  4001|   Respiratory|   1000|Product A|  M10|  Prev|Online Pharmacy|   201|    175|   641|
# +-------+--------+--------------------+------+--------------+-------+---------+-----+------+---------------+------+-------+------+
# only showing top 20 rows

# %%
# bringing in segment details

df_seg_sales = spark.sql("""select
                          terr_id,
                            sales.cust_id,
                            cust_nm,
                            mkt_id, 
                            mkt_nm,
                            prod_id,
                            prod_nm,
                            tb_nm,
                            tb_typ,
                            cust_typ,
                            seg_nm,
                            nrx_ct,
                            nbrx_ct,
                            trx_ct
                          from df_cust_sales sales
                          join
                          df_load_seg seg
                          on sales.cust_id = seg.cust_id
                          """)

df_seg_sales.createOrReplaceTempView("df_seg_sales")
df_seg_sales.show()
# Out:
# +-------+--------+--------------------+------+--------------+-------+---------+-----+------+---------------+------+------+-------+------+
# |terr_id| cust_id|             cust_nm|mkt_id|        mkt_nm|prod_id|  prod_nm|tb_nm|tb_typ|       cust_typ|seg_nm|nrx_ct|nbrx_ct|trx_ct|
# +-------+--------+--------------------+------+--------------+-------+---------+-----+------+---------------+------+------+-------+------+
# | 134289|ID136310|      Stephen Becker|  4000|         Renal|   1001|Product B|  M04|  Curr|   Supermarkets|  High|   506|    678|  1394|
# | 134321|ID136077|Kathleen Jenkins DVM|  4004|      Oncology|   1003|Product D|  M05|  Curr|   Supermarkets|  High|  1215|     87|  1455|
# | 134318|ID136079|      Jennifer Jones|  4000|         Renal|   1003|Product D|  M01|  Curr|        Clinics|Medium|  1028|    451|  1914|
# | 134314|ID135871|     Heather Simmons|  4003|Cardiovascular|   1003|Product D|  M04|  Curr|       Pharmacy|  High|   504|    369|  1346|
# | 134298|ID136173|   Nicholas Caldwell|  4001|   Respiratory|   1003|Product D|  M08|  Prev|        Clinics|Medium|  1176|    221|  1431|
# | 134313|ID135953|         Ariel Brown|  4000|         Renal|   1001|Product B|  M10|  Prev|   Supermarkets|Medium|   587|   1083|  1872|
# | 134318|ID136309|     Victoria Powell|  4000|         Renal|   1002|Product C|  M03|  Curr|   Supermarkets|Medium|   358|    982|  1533|
# | 134322|ID135632|    Michael Cisneros|  4002|      Diabetes|   1003|Product D|  M06|  Curr|      Hospitals|Medium|   440|    779|  1405|
# | 134323|ID136233|     Travis Carrillo|  4002|      Diabetes|   1001|Product B|  M05|  Curr|      Hospitals|  High|   793|   1473|  2540|
# | 134310|ID135894|    Elizabeth Branch|  4002|      Diabetes|   1001|Product B|  M09|  Prev|        Clinics|  High|  1095|    377|  1707|
# | 134314|ID136099|        Sharon Weiss|  4003|Cardiovascular|   1003|Product D|  M11|  Prev|      Hospitals|  High|  1873|    592|  2531|
# | 134293|ID136503|        Keith Burton|  4001|   Respiratory|   1003|Product D|  M03|  Curr|Online Pharmacy|  High|   872|   1267|  2359|
# | 134296|ID136025|          Todd Lewis|  4002|      Diabetes|   1001|Product B|  M11|  Prev|       Pharmacy|  High|  1423|    834|  2483|
# | 134323|ID135910|     Bonnie Thompson|  4003|Cardiovascular|   1003|Product D|  M04|  Curr|        Clinics|   Low|   833|    357|  1206|
# | 134320|ID136558|       Sara Sullivan|  4003|Cardiovascular|   1003|Product D|  M11|  Prev|      Hospitals|  High|  1435|    466|  2336|
# | 134303|ID135601|       Jackie Wagner|  4001|   Respiratory|   1000|Product A|  M08|  Prev|        Clinics|Medium|  1194|    237|  1797|
# | 134319|ID135765|         Emily Brown|  4000|         Renal|   1001|Product B|  M04|  Curr|      Hospitals|  High|   667|    242|  1297|
# | 134321|ID136240|    Brandon Williams|  4004|      Oncology|   1003|Product D|  M04|  Curr|      Hospitals|  High|  1529|   1246|  3078|
# | 134319|ID136285|    Andrew Hernandez|  4001|   Respiratory|   1000|Product A|  M07|  Prev|        Clinics|  High|   463|   1289|  2223|
# | 134322|ID136349|     Emily Singleton|  4001|   Respiratory|   1000|Product A|  M10|  Prev|Online Pharmacy|Medium|   201|    175|   641|
# +-------+--------+--------------------+------+--------------+-------+---------+-----+------+---------------+------+------+-------+------+
# only showing top 20 rows

# %%
# ranking hcps by nbrx
df_nbrx_sales = spark.sql("""
                          select
                            terr_id,
                            cust_id,
                            cust_nm,
                            mkt_id, 
                            mkt_nm,
                            prod_id,
                            prod_nm,
                            tb_nm,
                            tb_typ,
                            cust_typ,
                            seg_nm, 
                            nbrx_ct,
                            nrx_ct,
                            nbrx_ct,
                            trx_ct,
                            dense_rank() over (partition by terr_id order by nbrx_ct desc) as nbrx_rank
                          from df_seg_sales
                          where tb_nm = "Y"
                          and tb_typ = "Curr"
                          and prod_nm = "Product A" 
                          group by 
                           terr_id,
                            cust_id,
                            cust_nm,
                            mkt_id, 
                            mkt_nm,
                            prod_id,
                            prod_nm,
                            tb_nm,
                            tb_typ,
                            cust_typ,
                            seg_nm, 
                            nbrx_ct,
                            nrx_ct,
                            nbrx_ct,
                            trx_ct
                          """)
df_nbrx_sales.createOrReplaceTempView("df_nbrx_sales")
spark.sql("select * from df_nbrx_sales where nbrx_rank >1").show()
# df_nbrx_sales.show()
# Out:
# +-------+--------+--------------------+------+--------------+-------+---------+-----+------+---------------+-------+-------+------+-------+------+---------+
# |terr_id| cust_id|             cust_nm|mkt_id|        mkt_nm|prod_id|  prod_nm|tb_nm|tb_typ|       cust_typ| seg_nm|nbrx_ct|nrx_ct|nbrx_ct|trx_ct|nbrx_rank|
# +-------+--------+--------------------+------+--------------+-------+---------+-----+------+---------------+-------+-------+------+-------+------+---------+
# | 134287|ID135805|       Stephen Smith|  4002|      Diabetes|   1000|Product A|    Y|  Curr|        Clinics|   High|   1245|  1315|   1245|  2865|        2|
# | 134287|ID135846|Miss Elizabeth Evans|  4000|         Renal|   1000|Product A|    Y|  Curr|Online Pharmacy|    Low|   1049|  1169|   1049|  2286|        3|
# | 134287|ID136341|     Jennifer Tucker|  4004|      Oncology|   1000|Product A|    Y|  Curr|Online Pharmacy| Medium|    555|  1915|    555|  2619|        4|
# | 134287|ID136087|         Tami Robles|  4000|         Renal|   1000|Product A|    Y|  Curr|        Clinics|   High|     97|   110|     97|   387|        5|
# | 134287|ID135956|       Sarah Burnett|  4000|         Renal|   1000|Product A|    Y|  Curr|       Pharmacy|    Low|     44|   646|     44|  1049|        6|
# | 134292|ID136210|     Daniel Phillips|  4001|   Respiratory|   1000|Product A|    Y|  Curr|      Hospitals| Medium|    641|   600|    641|  1478|        2|
# | 134293|ID135936|        David Castro|  4002|      Diabetes|   1000|Product A|    Y|  Curr|Online Pharmacy| Medium|    954|   677|    954|  1865|        2|
# | 134293|ID135989|        Daniel Poole|  4001|   Respiratory|   1000|Product A|    Y|  Curr|Online Pharmacy|   High|    860|  1609|    860|  2625|        3|
# | 134293|ID135609|     Kimberly Murphy|  4002|      Diabetes|   1000|Product A|    Y|  Curr|   Supermarkets|Unknown|    544|  1006|    544|  1768|        4|
# | 134293|ID135786|          Mark Rivas|  4004|      Oncology|   1000|Product A|    Y|  Curr|        Clinics| Medium|    275|  1454|    275|  2179|        5|
# | 134293|ID135603|      Courtney Doyle|  4004|      Oncology|   1000|Product A|    Y|  Curr|       Pharmacy|    Low|    123|  1455|    123|  1918|        6|
# | 134294|ID136231|      Katelyn Fields|  4000|         Renal|   1000|Product A|    Y|  Curr|       Pharmacy| Medium|   1237|  1082|   1237|  2648|        2|
# | 134294|ID135660|        Russell Wong|  4000|         Renal|   1000|Product A|    Y|  Curr|      Hospitals|    Low|    830|   871|    830|  1723|        3|
# | 134294|ID136130|         Brian Young|  4004|      Oncology|   1000|Product A|    Y|  Curr|      Hospitals|   High|    161|   776|    161|  1050|        4|
# | 134294|ID135988|           Juan Webb|  4002|      Diabetes|   1000|Product A|    Y|  Curr|   Supermarkets|    Low|     89|   814|     89|  1020|        5|
# | 134295|ID136242|     Susan Donaldson|  4000|         Renal|   1000|Product A|    Y|  Curr|        Clinics| Medium|    963|   421|    963|  1876|        2|
# | 134295|ID136467|      Patricia Cowan|  4004|      Oncology|   1000|Product A|    Y|  Curr|        Clinics|    Low|    618|   938|    618|  1745|        3|
# | 134297|ID136486|    Rebecca Harrison|  4003|Cardiovascular|   1000|Product A|    Y|  Curr|       Pharmacy| Medium|    497|  1340|    497|  2108|        2|
# | 134298|ID136273|  Nathaniel Williams|  4000|         Renal|   1000|Product A|    Y|  Curr|Online Pharmacy|   High|    664|   684|    664|  1669|        2|
# | 134298|ID135620|      Annette Fisher|  4004|      Oncology|   1000|Product A|    Y|  Curr|        Clinics| Medium|    654|  1161|    654|  2314|        3|
# +-------+--------+--------------------+------+--------------+-------+---------+-----+------+---------------+-------+-------+------+-------+------+---------+
# only showing top 20 rows

# %%
# bringing in geography details

df_hcp_geo_sales = spark.sql("""select
                            sales.terr_id,
                            terr_nm, 
                            dist_nm, 
                            reg_nm, 
                            area_nm,
                            cust_id,
                            cust_nm,
                            mkt_id, 
                            mkt_nm,
                            prod_id,
                            prod_nm,
                            tb_nm,
                            tb_typ,
                            cust_typ,
                            seg_nm,
                            nbrx_rank,
                            nrx_ct,
                            nbrx_ct,
                            trx_ct
                          from df_nbrx_sales sales
                          join
                          df_load_geo geo
                          on sales.terr_id = geo.terr_id
                          """)

df_hcp_geo_sales.createOrReplaceTempView("df_hcp_geo_sales")
df_hcp_geo_sales.show()
# Out:
# +-------+-------+-------+---------+-------+--------+--------------------+------+-----------+-------+---------+-----+------+---------------+-------+---------+------+-------+------+
# |terr_id|terr_nm|dist_nm|   reg_nm|area_nm| cust_id|             cust_nm|mkt_id|     mkt_nm|prod_id|  prod_nm|tb_nm|tb_typ|       cust_typ| seg_nm|nbrx_rank|nrx_ct|nbrx_ct|trx_ct|
# +-------+-------+-------+---------+-------+--------+--------------------+------+-----------+-------+---------+-----+------+---------------+-------+---------+------+-------+------+
# | 134287| Terr 2| Dist 1|  South 1|  South|ID135984|          Erik Silva|  4004|   Oncology|   1000|Product A|    Y|  Curr|   Supermarkets| Medium|        1|  1208|   1320|  2917|
# | 134287| Terr 2| Dist 1|  South 1|  South|ID135805|       Stephen Smith|  4002|   Diabetes|   1000|Product A|    Y|  Curr|        Clinics|   High|        2|  1315|   1245|  2865|
# | 134287| Terr 2| Dist 1|  South 1|  South|ID135846|Miss Elizabeth Evans|  4000|      Renal|   1000|Product A|    Y|  Curr|Online Pharmacy|    Low|        3|  1169|   1049|  2286|
# | 134287| Terr 2| Dist 1|  South 1|  South|ID136341|     Jennifer Tucker|  4004|   Oncology|   1000|Product A|    Y|  Curr|Online Pharmacy| Medium|        4|  1915|    555|  2619|
# | 134287| Terr 2| Dist 1|  South 1|  South|ID136087|         Tami Robles|  4000|      Renal|   1000|Product A|    Y|  Curr|        Clinics|   High|        5|   110|     97|   387|
# | 134287| Terr 2| Dist 1|  South 1|  South|ID135956|       Sarah Burnett|  4000|      Renal|   1000|Product A|    Y|  Curr|       Pharmacy|    Low|        6|   646|     44|  1049|
# | 134289| Terr 1| Dist 2|   East 2|   East|ID135935|       Laura Gregory|  4002|   Diabetes|   1000|Product A|    Y|  Curr|        Clinics|    Low|        1|   290|     36|   578|
# | 134291| Terr 2| Dist 2|Central 1|Central|ID136040|      Sarah Anderson|  4001|Respiratory|   1000|Product A|    Y|  Curr|   Supermarkets|    Low|        1|  1069|   1284|  2643|
# | 134292| Terr 1| Dist 1|  North 1|  North|ID135776|       Teresa Taylor|  4002|   Diabetes|   1000|Product A|    Y|  Curr|        Clinics|   High|        1|   411|   1321|  1769|
# | 134292| Terr 1| Dist 1|  North 1|  North|ID136210|     Daniel Phillips|  4001|Respiratory|   1000|Product A|    Y|  Curr|      Hospitals| Medium|        2|   600|    641|  1478|
# | 134293| Terr 2| Dist 2|   East 1|   East|ID136473|        April Parker|  4001|Respiratory|   1000|Product A|    Y|  Curr|   Supermarkets| Medium|        1|   190|   1013|  1504|
# | 134293| Terr 2| Dist 2|   East 1|   East|ID135936|        David Castro|  4002|   Diabetes|   1000|Product A|    Y|  Curr|Online Pharmacy| Medium|        2|   677|    954|  1865|
# | 134293| Terr 2| Dist 2|   East 1|   East|ID135989|        Daniel Poole|  4001|Respiratory|   1000|Product A|    Y|  Curr|Online Pharmacy|   High|        3|  1609|    860|  2625|
# | 134293| Terr 2| Dist 2|   East 1|   East|ID135609|     Kimberly Murphy|  4002|   Diabetes|   1000|Product A|    Y|  Curr|   Supermarkets|Unknown|        4|  1006|    544|  1768|
# | 134293| Terr 2| Dist 2|   East 1|   East|ID135786|          Mark Rivas|  4004|   Oncology|   1000|Product A|    Y|  Curr|        Clinics| Medium|        5|  1454|    275|  2179|
# | 134293| Terr 2| Dist 2|   East 1|   East|ID135603|      Courtney Doyle|  4004|   Oncology|   1000|Product A|    Y|  Curr|       Pharmacy|    Low|        6|  1455|    123|  1918|
# | 134294| Terr 1| Dist 2|   East 1|   East|ID135619|      Christie Brown|  4002|   Diabetes|   1000|Product A|    Y|  Curr|        Clinics|   High|        1|   783|   1454|  2665|
# | 134294| Terr 1| Dist 2|   East 1|   East|ID136231|      Katelyn Fields|  4000|      Renal|   1000|Product A|    Y|  Curr|       Pharmacy| Medium|        2|  1082|   1237|  2648|
# | 134294| Terr 1| Dist 2|   East 1|   East|ID135660|        Russell Wong|  4000|      Renal|   1000|Product A|    Y|  Curr|      Hospitals|    Low|        3|   871|    830|  1723|
# | 134294| Terr 1| Dist 2|   East 1|   East|ID136130|         Brian Young|  4004|   Oncology|   1000|Product A|    Y|  Curr|      Hospitals|   High|        4|   776|    161|  1050|
# +-------+-------+-------+---------+-------+--------+--------------------+------+-----------+-------+---------+-----+------+---------------+-------+---------+------+-------+------+
# only showing top 20 rows

# %%
#pushing HCP level ranked fact to s3

# Defining s3 write path
s3_path = "s3://amazon-l2-reporting-prod/datalake/"+"hcp_sales/"
#print (s3_path)

df_hcp_geo_sales_final = spark.sql("""select
                            *, now() as load_dt
                          from df_hcp_geo_sales
                          """)
df_hcp_geo_sales_final.createOrReplaceTempView("df_hcp_geo_sales_final")
df_hcp_geo_sales_final.show()

# Write parquet file to s3

df_hcp_geo_sales_final.write.parquet(s3_path)
# Out:
# +-------+-------+-------+---------+-------+--------+--------------------+------+-----------+-------+---------+-----+------+---------------+-------+---------+------+-------+------+--------------------+
# |terr_id|terr_nm|dist_nm|   reg_nm|area_nm| cust_id|             cust_nm|mkt_id|     mkt_nm|prod_id|  prod_nm|tb_nm|tb_typ|       cust_typ| seg_nm|nbrx_rank|nrx_ct|nbrx_ct|trx_ct|             load_dt|
# +-------+-------+-------+---------+-------+--------+--------------------+------+-----------+-------+---------+-----+------+---------------+-------+---------+------+-------+------+--------------------+
# | 134293| Terr 2| Dist 2|   East 1|   East|ID135786|          Mark Rivas|  4004|   Oncology|   1000|Product A|    Y|  Curr|        Clinics| Medium|        5|  1454|    275|  2179|2025-11-10 05:12:...|
# | 134293| Terr 2| Dist 2|   East 1|   East|ID135603|      Courtney Doyle|  4004|   Oncology|   1000|Product A|    Y|  Curr|       Pharmacy|    Low|        6|  1455|    123|  1918|2025-11-10 05:12:...|
# | 134294| Terr 1| Dist 2|   East 1|   East|ID135619|      Christie Brown|  4002|   Diabetes|   1000|Product A|    Y|  Curr|        Clinics|   High|        1|   783|   1454|  2665|2025-11-10 05:12:...|
# | 134294| Terr 1| Dist 2|   East 1|   East|ID136231|      Katelyn Fields|  4000|      Renal|   1000|Product A|    Y|  Curr|       Pharmacy| Medium|        2|  1082|   1237|  2648|2025-11-10 05:12:...|
# | 134294| Terr 1| Dist 2|   East 1|   East|ID135660|        Russell Wong|  4000|      Renal|   1000|Product A|    Y|  Curr|      Hospitals|    Low|        3|   871|    830|  1723|2025-11-10 05:12:...|
# | 134294| Terr 1| Dist 2|   East 1|   East|ID136130|         Brian Young|  4004|   Oncology|   1000|Product A|    Y|  Curr|      Hospitals|   High|        4|   776|    161|  1050|2025-11-10 05:12:...|
# +-------+-------+-------+---------+-------+--------+--------------------+------+-----------+-------+---------+-----+------+---------------+-------+---------+------+-------+------+--------------------+
# only showing top 20 rows

# %%
# dropping customer grain and aggregating sales
# calculating market volume
# creating a bucket for all customer types

df_mkt_sales = spark.sql("""
    WITH base_sales AS (
        SELECT
            terr_id,
            terr_nm, 
            dist_nm, 
            reg_nm, 
            area_nm,
            mkt_id, 
            mkt_nm,
            prod_id,
            prod_nm,
            tb_nm,
            tb_typ,
            cust_typ,
            seg_nm,
            SUM(nrx_ct) AS nrx_ct,
            SUM(nbrx_ct) AS nbrx_ct,
            SUM(trx_ct) AS trx_ct
        FROM
            df_geo_sales
        GROUP BY 
            terr_id,
            terr_nm, 
            dist_nm, 
            reg_nm, 
            area_nm,
            mkt_id, 
            mkt_nm,
            prod_id,
            prod_nm,
            tb_nm,
            tb_typ,
            cust_typ,
            seg_nm
    ),
    all_sales AS (
        SELECT
            terr_id,
            terr_nm, 
            dist_nm, 
            reg_nm, 
            area_nm,
            mkt_id, 
            mkt_nm,
            prod_id,
            prod_nm,
            tb_nm,
            tb_typ,
            'ALL' AS cust_typ,
            seg_nm,
            SUM(nrx_ct) AS nrx_ct,
            SUM(nbrx_ct) AS nbrx_ct,
            SUM(trx_ct) AS trx_ct
        FROM base_sales
        GROUP BY
            terr_id,
            terr_nm, 
            dist_nm, 
            reg_nm, 
            area_nm,
            mkt_id, 
            mkt_nm,
            prod_id,
            prod_nm,
            tb_nm,
            tb_typ,
            seg_nm
    )
    select
        *,
        SUM(nrx_ct) OVER (
            PARTITION BY terr_id, mkt_id, tb_nm, tb_typ
        ) AS nrx_mkt_vol,
        SUM(nbrx_ct) OVER (
            PARTITION BY terr_id, mkt_id, tb_nm, tb_typ
        ) AS nbrx_mkt_vol,
        SUM(trx_ct) OVER (
            PARTITION BY terr_id, mkt_id, tb_nm, tb_typ
        ) AS trx_mkt_vol
    from base_sales

    union all

    select
        *,
        SUM(nrx_ct) OVER (
            PARTITION BY terr_id, mkt_id, tb_nm, tb_typ
        ) AS nrx_mkt_vol,
        SUM(nbrx_ct) OVER (
            PARTITION BY terr_id, mkt_id, tb_nm, tb_typ
        ) AS nbrx_mkt_vol,
        SUM(trx_ct) OVER (
            PARTITION BY terr_id, mkt_id, tb_nm, tb_typ
        ) AS trx_mkt_vol
    FROM all_sales
""")
df_mkt_sales.createOrReplaceTempView("df_mkt_sales")
display(df_mkt_sales)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>terr_id</th><th>terr_nm</th><th>dist_nm</th><th>reg_nm</th><th>area_nm</th><th>mkt_id</th><th>mkt_nm</th><th>prod_id</th><th>prod_nm</th><th>tb_nm</th><th>tb_typ</th><th>cust_typ</th><th>seg_nm</th><th>nrx_ct</th><th>nbrx_ct</th><th>trx_ct</th><th>nrx_mkt_vol</th><th>nbrx_mkt_vol</th><th>trx_mkt_vol</th></tr></thead><tbody><tr><td>134287</td><td>Terr 2</td><td>Dist 1</td><td>South 1</td><td>South</td><td>4000</td><td>Renal</td><td>1000</td><td>Product A</td><td>Y</td><td>Curr</td><td>Clinics</td><td>High</td><td>110</td><td>97</td><td>387</td><td>1925</td><td>1190</td><td>3722</td></tr><tr><td>134287</td><td>Terr 2</td><td>Dist 1</td><td>South 1</td><td>South</td><td>4000</td><td>Renal</td><td>1000</td><td>Product A</td><td>Y</td><td>Curr</td><td>Pharmacy</td><td>Low</td><td>646</td><td>44</td><td>1049</td><td>1925</td><td>1190</td><td>3722</td></tr><tr><td>134287</td><td>Terr 2</td><td>Dist 1</td><td>South 1</td><td>South</td><td>4000</td><td>Renal</td><td>1000</td><td>Product A</td><td>Y</td><td>Curr</td><td>Online Pharmacy</td><td>Low</td><td>1169</td><td>1049</td><td>2286</td><td>1925</td><td>1190</td><td>3722</td></tr><tr><td>134287</td><td>Terr 2</td><td>Dist 1</td><td>South 1</td><td>South</td><td>4002</td><td>Diabetes</td><td>1000</td><td>Product A</td><td>Y</td><td>Curr</td><td>Clinics</td><td>High</td><td>1315</td><td>1245</td><td>2865</td><td>1315</td><td>1245</td><td>2865</td></tr><tr><td>134287</td><td>Terr 2</td><td>Dist 1</td><td>South 1</td><td>South</td><td>4004</td><td>Oncology</td><td>1000</td><td>Product A</td><td>Y</td><td>Curr</td><td>Online Pharmacy</td><td>Medium</td><td>1915</td><td>555</td><td>2619</td><td>3123</td><td>1875</td><td>5536</td></tr><tr><td>134287</td><td>Terr 2</td><td>Dist 1</td><td>South 1</td><td>South</td><td>4004</td><td>Oncology</td><td>1000</td><td>Product A</td><td>Y</td><td>Curr</td><td>Supermarkets</td><td>Medium</td><td>1208</td><td>1320</td><td>2917</td><td>3123</td><td>1875</td><td>5536</td></tr><tr><td>134289</td><td>Terr 1</td><td>Dist 2</td><td>East 2</td><td>East</td><td>4002</td><td>Diabetes</td><td>1000</td><td>Product A</td><td>Y</td><td>Curr</td><td>Clinics</td><td>Low</td><td>290</td><td>36</td><td>578</td><td>290</td><td>36</td><td>578</td></tr><tr><td>134291</td><td>Terr 2</td><td>Dist 2</td><td>Central 1</td><td>Central</td><td>4001</td><td>Respiratory</td><td>1000</td><td>Product A</td><td>Y</td><td>Curr</td><td>Supermarkets</td><td>Low</td><td>1069</td><td>1284</td><td>2643</td><td>1069</td><td>1284</td><td>2643</td></tr><tr><td>134292</td><td>Terr 1</td><td>Dist 1</td><td>North 1</td><td>North</td><td>4001</td><td>Respiratory</td><td>1000</td><td>Product A</td><td>Y</td><td>Curr</td><td>Hospitals</td><td>Medium</td><td>600</td><td>641</td><td>1478</td><td>600</td><td>641</td><td>1478</td></tr><tr><td>134292</td><td>Terr 1</td><td>Dist 1</td><td>North 1</td><td>North</td><td>4002</td><td>Diabetes</td><td>1000</td><td>Product A</td><td>Y</td><td>Curr</td><td>Clinics</td><td>High</td><td>411</td><td>1321</td><td>1769</td><td>411</td><td>1321</td><td>1769</td></tr><tr><td>134293</td><td>Terr 2</td><td>Dist 2</td><td>East 1</td><td>East</td><td>4001</td><td>Respiratory</td><td>1000</td><td>Product A</td><td>Y</td><td>Curr</td><td>Supermarkets</td><td>Medium</td><td>190</td><td>1013</td><td>1504</td><td>1799</td><td>1873</td><td>4129</td></tr><tr><td>134293</td><td>Terr 2</td><td>Dist 2</td><td>East 1</td><td>East</td><td>4001</td><td>Respiratory</td><td>1000</td><td>Product A</td><td>Y</td><td>Curr</td><td>Online Pharmacy</td><td>High</td><td>1609</td><td>860</td><td>2625</td><td>1799</td><td>1873</td><td>4129</td></tr><tr><td>134293</td><td>Terr 2</td><td>Dist 2</td><td>East 1</td><td>East</td><td>4002</td><td>Diabetes</td><td>1000</td><td>Product A</td><td>Y</td><td>Curr</td><td>Supermarkets</td><td>Unknown</td><td>1006</td><td>544</td><td>1768</ ...

# %%
# aggregating sales at different geo levels
df_agg_sales = spark.sql("""
        SELECT
            "" as terr_id,
            "" as terr_nm, 
            dist_nm, 
            reg_nm, 
            area_nm,
            "Nation" as nat_nm,
            mkt_id, 
            mkt_nm,
            prod_id,
            prod_nm,
            tb_nm,
            tb_typ,
            cust_typ,
            seg_nm,
            SUM(nrx_ct) AS nrx_ct,
            SUM(nbrx_ct) AS nbrx_ct,
            SUM(trx_ct) AS trx_ct,
            SUM(nrx_mkt_vol) AS nrx_mkt_vol,
            SUM(nbrx_mkt_vol) AS nbrx_mkt_vol,
            SUM(trx_mkt_vol) AS trx_mkt_vol
        FROM
            df_mkt_sales
            group BY
            dist_nm, 
            reg_nm, 
            area_nm,
            mkt_id, 
            mkt_nm,
            prod_id,
            prod_nm,
            tb_nm,
            tb_typ,
            cust_typ,
            seg_nm
           
            """)

df_agg_sales.createOrReplaceTempView("df_agg_sales")
display(df_agg_sales)

df_agg_sales_reg = spark.sql("""
        SELECT
            "" as terr_id,
            "" as terr_nm, 
            "" as dist_nm, 
            reg_nm, 
            area_nm,
            "Nation" as nat_nm,
            mkt_id, 
            mkt_nm,
            prod_id,
            prod_nm,
            tb_nm,
            tb_typ,
            cust_typ,
            seg_nm,
            SUM(nrx_ct) AS nrx_ct,
            SUM(nbrx_ct) AS nbrx_ct,
            SUM(trx_ct) AS trx_ct,
            SUM(nrx_mkt_vol) AS nrx_mkt_vol,
            SUM(nbrx_mkt_vol) AS nbrx_mkt_vol,
            SUM(trx_mkt_vol) AS trx_mkt_vol
        FROM
            df_mkt_sales
            group BY 
            reg_nm, 
            area_nm,
            mkt_id, 
            mkt_nm,
            prod_id,
            prod_nm,
            tb_nm,
            tb_typ,
            cust_typ,
            seg_nm
           
            """)

df_agg_sales_reg.createOrReplaceTempView("df_agg_sales_reg")
display(df_agg_sales_reg)

df_agg_sales_area = spark.sql("""
        SELECT
            "" as terr_id,
            "" as terr_nm, 
            "" as dist_nm, 
            "" as reg_nm, 
            area_nm,
            "Nation" as nat_nm,
            mkt_id, 
            mkt_nm,
            prod_id,
            prod_nm,
            tb_nm,
            tb_typ,
            cust_typ,
            seg_nm,
            SUM(nrx_ct) AS nrx_ct,
            SUM(nbrx_ct) AS nbrx_ct,
            SUM(trx_ct) AS trx_ct,
            SUM(nrx_mkt_vol) AS nrx_mkt_vol,
            SUM(nbrx_mkt_vol) AS nbrx_mkt_vol,
            SUM(trx_mkt_vol) AS trx_mkt_vol
        FROM
            df_mkt_sales
            group BY 
            area_nm,
            mkt_id, 
            mkt_nm,
            prod_id,
            prod_nm,
            tb_nm,
            tb_typ,
            cust_typ,
            seg_nm
           
            """)

df_agg_sales_area.createOrReplaceTempView("df_agg_sales_area")
display(df_agg_sales_area)


df_agg_sales_nat = spark.sql("""
        SELECT
            "" as terr_id,
            "" as terr_nm, 
            "" as dist_nm, 
            "" as reg_nm, 
            "" as area_nm,
            "Nation" as nat_nm,
            mkt_id, 
            mkt_nm,
            prod_id,
            prod_nm,
            tb_nm,
            tb_typ,
            cust_typ,
            seg_nm,
            SUM(nrx_ct) AS nrx_ct,
            SUM(nbrx_ct) AS nbrx_ct,
            SUM(trx_ct) AS trx_ct,
            SUM(nrx_mkt_vol) AS nrx_mkt_vol,
            SUM(nbrx_mkt_vol) AS nbrx_mkt_vol,
            SUM(trx_mkt_vol) AS trx_mkt_vol
        FROM
            df_mkt_sales
            group BY 
            
            mkt_id, 
            mkt_nm,
            prod_id,
            prod_nm,
            tb_nm,
            tb_typ,
            cust_typ,
            seg_nm
           
            """)

df_agg_sales_nat.createOrReplaceTempView("df_agg_sales_nat")
display(df_agg_sales_nat)


# union all the dfs at end
df_agg_sales_all = df_agg_sales.unionByName(df_agg_sales_reg).unionByName(df_agg_sales_area).unionByName(df_agg_sales_nat)
display(df_agg_sales_all)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th